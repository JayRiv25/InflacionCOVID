# %% [markdown]
# <a href="https://colab.research.google.com/github/JayRiv25/InflacionCOVID/blob/main/Inflaci%C3%B3n_Post_COVID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Datos COVID
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga de datos
#NOTA: Separa la fecha 'date' en mes y año
df = pd.read_csv("/content/covid_global.csv", low_memory=False)
df.head(100)
# Out:
#    country     date  inflation_rate  interest_rate  oil_price  gdp_growth  \
# 0      USA  2020-01            0.33           5.76      34.44        0.34
# 1      USA  2020-02            4.12           4.33      44.75        0.02
# 2      USA  2020-03            2.75           4.24      52.80        0.30
# 3      USA  2020-04            4.36           4.52      39.19        2.28
# 4      USA  2020-05            2.73           3.17      41.09        3.05
# ..     ...      ...             ...            ...        ...         ...
# 95     VNM  2022-12            4.22           2.03     136.94        3.17
# 96     VNM  2023-01            5.69           3.54      63.97        1.96
# 97     VNM  2023-02            4.94           2.43      70.75        6.69
# 98     VNM  2023-03            5.36           2.91      81.56        5.76
# 99     VNM  2023-04            4.76           1.77      68.46        5.56
#
#     unemployment_rate  money_supply_m2  exchange_rate_usd  food_price_index  \
# ...

# %%
df.shape
# Out:
# (100000, 11)

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df.isnull().sum()
# Out:
# country               0
# date                  0
# inflation_rate        0
# interest_rate         0
# oil_price             0
# gdp_growth            0
# unemployment_rate     0
# money_supply_m2       0
# exchange_rate_usd     0
# food_price_index      0
# supply_chain_index    0
# dtype: int64

# %%
#Agrupación de las columnas por tipo de datos
tipos = df.columns.to_series().groupby(df.dtypes).groups

#Conociendo la lista de columnas categóricas
ctext = tipos[np.dtype('object')]
len(ctext) #Cantidad de columnas con datos categóricos
# Out:
# 2

# %%
#Conociendo la lista de columnas numéricas
columnas = df.columns
cnum = list(set(columnas) - set(ctext))
len(cnum)
# Out:
# 9
